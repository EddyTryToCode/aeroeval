# %% [markdown]
# # VisDrone-DET Exploratory Data Analysis
# Phân tích chuyên sâu về đặc tính tập dữ liệu VisDrone2019-DET:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

reports_dir = Path("../reports")
df_stats = pd.read_csv(reports_dir / "dataset_statistics.csv")
df_stats
# Out:
#       Split  Total_Images  Total_Valid_Objects  Avg_Objects_Per_Image  \
# 0     Train          6471               343204                  53.04
# 1       Val           548                38759                  70.73
# 2  Combined          7019               381963                  54.42
#
#    Median_Objects_Per_Image  Min_Objects_In_Image  Max_Objects_In_Image  \
# 0                      42.0                     1                   902
# 1                      65.0                     1                   317
# 2                      43.0                     1                   902
#
#    Small_Objects_Count  Small_Objects_Pct  Medium_Objects_Count  \
# 0               207524              60.47                116704
# 1                26575              68.56                 11117
# 2               234099              61.29                127821
#
#    Medium_Objects_Pct  Large_Objects_Count  Large_Objects_Pct  \
# 0               34.00                18976               5.53
# ...

# %%
# Hiển thị các biểu đồ phân phối
from IPython.display import Image, display

for plot_name in ["class_distribution.png", "object_size_distribution.png", "objects_per_image.png", "bbox_dimensions.png", "image_resolution_distribution.png"]:
    print(f"=== {plot_name} ===")
    display(Image(filename=str(reports_dir / plot_name)))
# Out:
# === class_distribution.png ===
# === object_size_distribution.png ===
# === objects_per_image.png ===
# === bbox_dimensions.png ===
# === image_resolution_distribution.png ===
